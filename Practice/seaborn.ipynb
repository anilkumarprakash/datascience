# %% [markdown]
# # Seaborn
# Types of function
# - Figure level
# - Axes levels
#
# Types of Plots
# - Relational plot (scatter, Line)
# - Distribution plot (Histogram, kcd, regplot)
# - Categorical Plot (bar, count, box, voilin, swam)
# - Matrix plot (heatmap, clustermap)
# - Regression plot
# - Multi plot (joint, pair)

# %%
# %pip install seaborn

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

data = sns.load_dataset("tips")
data.head(50)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# ...

# %% [markdown]
# Scatterplot

# %%
sns.scatterplot(x='total_bill', y='tip', data=data)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Relplot
# - relplot can used instead of scatterplot

# %%
sns.relplot(x='total_bill', y='tip', kind='scatter', data=data)
plt.xlabel('Total Bill')
plt.ylabel('Tip Amount')
# Out:
# Text(13.819444444444445, 0.5, 'Tip Amount')

# %%
sns.scatterplot(x='total_bill', y='tip', data=data, hue='smoker', style='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x='total_bill', y='tip', data=data, hue='smoker', style='time', size='size', kind='scatter')

# %%
sns.relplot(x='total_bill', y='tip', data=data, col='smoker', kind='scatter')

# %% [markdown]
# Lineplot

# %%
x = np.array([2, 4, 6 , 8, 10])
y = np.array([21, 12, 33, 44, 50])
sns.lineplot(x=x, y=y)
# Out:
# <Axes: >

# %%
sns.relplot(x=x,y=y, kind='line')

# %% [markdown]
# # Distribution Plots
# - histplot
# - kdeplot
# - ecdfplot
# - displot
# - jointplot

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(x='total_bill', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(tips['day'], kind='hist')

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.displot(x='survived', kind='hist', data=titanic , element='step' )

# %% [markdown]
# # kdeplot

# %%
sns.kdeplot(x='age', data=titanic, fill=True, hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.displot(tips['total_bill'], kind='kde', fill=True)

# %%
sns.displot(tips['total_bill'], kde=True)

# %% [markdown]
# # rugplot

# %%
sns.displot(tips['total_bill'], kind='kde', fill=True)
sns.rugplot(x='total_bill', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# # Matrix plot
# - histmap
# - clustermap

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # histmap
# - it is a axes level function

# %%
temp = tips.pivot_table(index='day', columns='time', values='total_bill', aggfunc='mean')
sns.heatmap(temp, annot=True, fmt=".1f", cmap='YlGnBu', linewidths=0.5)  

# linewidths: width of lines that will divide each cell
# annot: annotation on cells
# fmt: format of annotation (e.g., .1f for one decimal places)
# cmap: color map
plt.figure(figsize=(8, 6))
# Out:
# /tmp/ipykernel_1859/3531585798.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   temp = tips.pivot_table(index='day', columns='time', values='total_bill', aggfunc='mean')

# %% [markdown]
# # Categorical Plot
# - bar
# - count
# - box
# - voilin
# - swam

# %% [markdown]
# # Categorical Scatter Plot
# * Stripplot
# * Swarmplot

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # strip plot

# %%
sns.stripplot(x='day', y='total_bill', data=tips, jitter=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # catplot

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='strip', jitter=True)

# %% [markdown]
# # swarm plot

# %%
sns.swarmplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='swarm', hue='sex')

# %% [markdown]
# # Categorical Distribution Plot
# * boxplot
# * voilinplot

# %% [markdown]
# * boxplot

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # FacetPlot

# %%
sns.catplot(x='day', y='total_bill', data=tips, col ='day', row='time', kind='box')

# %%
g = sns.FacetGrid(data=tips, col='day', row='time').map(sns.scatterplot,'sex', 'total_bill')

# %% [markdown]
# # pairplot

# %%
sns.pairplot(tips, hue='sex')

# %%
sns.PairGrid(data=tips).map(sns.histplot)
